# %% [markdown]
# <a href="https://colab.research.google.com/github/oviccenzo/inteligencia-artificial/blob/main/criei_o_dataset_dos_dados_da_pessoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importacao da biblioteca e os dados da pessoas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'Idade' : [18,15,12,29,34,50,60,56,74,80],
    'CPF' : [129394934199,299934234190,944599690199,234539599134,
             539634870230 ,560495434139 ,699649665199 ,795740749239
             ,734546634539 ,895995795695],
    'Idioma nativa' : ['1 alemão','2 inglês', '3 coreano','4 italiano','5 chinês','6 francês',
                       '7 esperanto', '8 mandarim','9 japônes','10 germânico'],
    'Altura' :[1.83,1.79,1.85,1.55,1.59,1.95,1.75,1.89,2.00,2.21],
    'Salario' : [5000,5995,4095,4954,3954,2954,5099,5595,5454,4959],
    'CEP' : [35400278,30200198,54599549,34999178,20595958,22595395,29545190,54999111,28540908,98595918],
    'Estado civil' : ['casado','solteiro','divorciado','solteira','divorciada','solteira','viúva',
    'viúvo','casado','casada']
    # '' : ['']
    })

# %%
df
# Out:
#    Idade           CPF Idioma nativa  Altura  Salario       CEP Estado civil
# 0     18  129394934199      1 alemão    1.83     5000  35400278       casado
# 1     15  299934234190      2 inglês    1.79     5995  30200198     solteiro
# 2     12  944599690199     3 coreano    1.85     4095  54599549   divorciado
# 3     29  234539599134    4 italiano    1.55     4954  34999178     solteira
# 4     34  539634870230      5 chinês    1.59     3954  20595958   divorciada
# 5     50  560495434139     6 francês    1.95     2954  22595395     solteira
# 6     60  699649665199   7 esperanto    1.75     5099  29545190        viúva
# 7     56  795740749239    8 mandarim    1.89     5595  54999111        viúvo
# 8     74  734546634539     9 japônes    2.00     5454  28540908       casado
# 9     80  895995795695  10 germânico    2.21     4959  98595918       casada

# %% [markdown]
# #Removendo a coluna idioma nativas

# %%
colunas = ['Idade','CPF','Altura','Salario','CEP']
df = df[colunas]

# %%
df
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199    1.83     5000  35400278
# 1     15  299934234190    1.79     5995  30200198
# 2     12  944599690199    1.85     4095  54599549
# 3     29  234539599134    1.55     4954  34999178
# 4     34  539634870230    1.59     3954  20595958
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %% [markdown]
# #todas as funções de matematica

# %%
print(df.median())
# Out:
# Idade      4.200000e+01
# CPF        6.300725e+11
# Altura     1.840000e+00
# Salario    4.979500e+03
# CEP        3.259969e+07
# dtype: float64

# %%
print(df.count())
# Out:
# Idade      10
# CPF        10
# Altura     10
# Salario    10
# CEP        10
# dtype: int64

# %%
print(df.idxmax())
# Out:
# Idade      9
# CPF        2
# Altura     9
# Salario    1
# CEP        9
# dtype: int64

# %%
print(df.idxmin())
# Out:
# Idade      2
# CPF        0
# Altura     3
# Salario    5
# CEP        4
# dtype: int64

# %%
print(df.value_counts())
# Out:
# Idade  CPF           Altura  Salario  CEP
# 12     944599690199  1.85    4095     54599549    1
# 15     299934234190  1.79    5995     30200198    1
# 18     129394934199  1.83    5000     35400278    1
# 29     234539599134  1.55    4954     34999178    1
# 34     539634870230  1.59    3954     20595958    1
# 50     560495434139  1.95    2954     22595395    1
# 56     795740749239  1.89    5595     54999111    1
# 60     699649665199  1.75    5099     29545190    1
# 74     734546634539  2.00    5454     28540908    1
# 80     895995795695  2.21    4959     98595918    1
# Name: count, dtype: int64

# %%
print(df.value_counts())
# Out:
# Idade  CPF           Altura  Salario  CEP
# 12     944599690199  1.85    4095     54599549    1
# 15     299934234190  1.79    5995     30200198    1
# 18     129394934199  1.83    5000     35400278    1
# 29     234539599134  1.55    4954     34999178    1
# 34     539634870230  1.59    3954     20595958    1
# 50     560495434139  1.95    2954     22595395    1
# 56     795740749239  1.89    5595     54999111    1
# 60     699649665199  1.75    5099     29545190    1
# 74     734546634539  2.00    5454     28540908    1
# 80     895995795695  2.21    4959     98595918    1
# Name: count, dtype: int64

# %%
print(df.corr())
# Out:
#             Idade       CPF    Altura   Salario       CEP
# Idade    1.000000  0.544128  0.611567  0.087638  0.364061
# CPF      0.544128  1.000000  0.553988 -0.133788  0.532082
# Altura   0.611567  0.553988  1.000000  0.045627  0.655372
# Salario  0.087638 -0.133788  0.045627  1.000000  0.186964
# CEP      0.364061  0.532082  0.655372  0.186964  1.000000

# %%
print(df.tail())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
print(df.abs())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199    1.83     5000  35400278
# 1     15  299934234190    1.79     5995  30200198
# 2     12  944599690199    1.85     4095  54599549
# 3     29  234539599134    1.55     4954  34999178
# 4     34  539634870230    1.59     3954  20595958
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
print(df.nunique())
# Out:
# Idade      10
# CPF        10
# Altura     10
# Salario    10
# CEP        10
# dtype: int64

# %%
print(df.var())
# Out:
# Idade      6.092889e+02
# CPF        8.002736e+22
# Altura     3.716556e-02
# Salario    8.095859e+05
# CEP        5.470790e+14
# dtype: float64

# %%
print(df.max())
# Out:
# Idade      8.000000e+01
# CPF        9.445997e+11
# Altura     2.210000e+00
# Salario    5.995000e+03
# CEP        9.859592e+07
# dtype: float64

# %%
print(df.min())
# Out:
# Idade      1.200000e+01
# CPF        1.293949e+11
# Altura     1.550000e+00
# Salario    2.954000e+03
# CEP        2.059596e+07
# dtype: float64

# %%
print(df.mode())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     12  129394934199    1.55     2954  20595958
# 1     15  234539599134    1.59     3954  22595395
# 2     18  299934234190    1.75     4095  28540908
# 3     29  539634870230    1.79     4954  29545190
# 4     34  560495434139    1.83     4959  30200198
# 5     50  699649665199    1.85     5000  34999178
# 6     56  734546634539    1.89     5099  35400278
# 7     60  795740749239    1.95     5454  54599549
# 8     74  895995795695    2.00     5595  54999111
# 9     80  944599690199    2.21     5995  98595918

# %%
print(df.describe())
# Out:
#            Idade           CPF     Altura      Salario           CEP
# count  10.000000  1.000000e+01  10.000000    10.000000  1.000000e+01
# mean   42.800000  5.834532e+11   1.841000  4805.900000  4.100717e+07
# std    24.683778  2.828911e+11   0.192784   899.769903  2.338972e+07
# min    12.000000  1.293949e+11   1.550000  2954.000000  2.059596e+07
# 25%    20.750000  3.598594e+11   1.760000  4309.750000  2.879198e+07
# 50%    42.000000  6.300725e+11   1.840000  4979.500000  3.259969e+07
# 75%    59.000000  7.804422e+11   1.935000  5365.250000  4.979973e+07
# max    80.000000  9.445997e+11   2.210000  5995.000000  9.859592e+07

# %%
print(df.sum())
# Out:
# Idade      4.280000e+02
# CPF        5.834532e+12
# Altura     1.841000e+01
# Salario    4.805900e+04
# CEP        4.100717e+08
# dtype: float64

# %%
print(df.round())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199     2.0     5000  35400278
# 1     15  299934234190     2.0     5995  30200198
# 2     12  944599690199     2.0     4095  54599549
# 3     29  234539599134     2.0     4954  34999178
# 4     34  539634870230     2.0     3954  20595958
# 5     50  560495434139     2.0     2954  22595395
# 6     60  699649665199     2.0     5099  29545190
# 7     56  795740749239     2.0     5595  54999111
# 8     74  734546634539     2.0     5454  28540908
# 9     80  895995795695     2.0     4959  98595918

# %% [markdown]
# # df['salario'].max()

# %%
df['Idade'].max()
# Out:
# 80

# %%
df['CPF'].max()
# Out:
# 944599690199

# %%
df['Altura'].max()
# Out:
# 2.21

# %%
df['Salario'].max()
# Out:
# 5995

# %%
df['CEP'].max()
# Out:
# 98595918

# %% [markdown]
# #df['idade'].min

# %%
df['Idade'].min()
# Out:
# 12

# %%
df['CPF'].min()
# Out:
# 129394934199

# %%
df['Altura'].min()
# Out:
# 1.55

# %%
df['Salario'].min()
# Out:
# 2954

# %%
df['CEP'].min()
# Out:
# 20595958

# %% [markdown]
# #std é o desvio padrão

# %%
print(df)
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199    1.83     5000  35400278
# 1     15  299934234190    1.79     5995  30200198
# 2     12  944599690199    1.85     4095  54599549
# 3     29  234539599134    1.55     4954  34999178
# 4     34  539634870230    1.59     3954  20595958
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
print(f"O desvio padrao CPF: {df["CPF"].std()}")
print(f"O desvio padrao idade: {df['Idade'].std()}")
print(f"O desvio padrao salario: {df['Salario'].std()}")
print(f"O desvio padrao altura: {df['Altura'].std()}")
print(f"O desvio padrao CEP: {df['CEP'].std()}")
# Out:
# O desvio padrao CPF: 282891072121.9715
# O desvio padrao idade: 24.683777848799583
# O desvio padrao salario: 899.7699026850019
# O desvio padrao altura: 0.192783701477992
# O desvio padrao CEP: 23389719.093243893

# %% [markdown]
# #mean e o calculo da media

# %%
print(df)
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199    1.83     5000  35400278
# 1     15  299934234190    1.79     5995  30200198
# 2     12  944599690199    1.85     4095  54599549
# 3     29  234539599134    1.55     4954  34999178
# 4     34  539634870230    1.59     3954  20595958
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
print(f"A media do salario eh:\n{df['Salario']}")
# Out:
# A media do salario eh:
# 0    5000
# 1    5995
# 2    4095
# 3    4954
# 4    3954
# 5    2954
# 6    5099
# 7    5595
# 8    5454
# 9    4959
# Name: Salario, dtype: int64

# %%
print(f"A media é: \n{df['Idade']}")
# Out:
# A media é:
# 0    18
# 1    15
# 2    12
# 3    29
# 4    34
# 5    50
# 6    60
# 7    56
# 8    74
# 9    80
# Name: Idade, dtype: int64

# %%
print(f"A media do CPF eh:\n{df['CPF']}")
# Out:
# A media do CPF eh:
# 0    129394934199
# 1    299934234190
# 2    944599690199
# 3    234539599134
# 4    539634870230
# 5    560495434139
# 6    699649665199
# 7    795740749239
# 8    734546634539
# 9    895995795695
# Name: CPF, dtype: int64

# %%
print(f"A media eh: altura\n{df['Altura']}")
# Out:
# A media eh: altura
# 0    1.83
# 1    1.79
# 2    1.85
# 3    1.55
# 4    1.59
# 5    1.95
# 6    1.75
# 7    1.89
# 8    2.00
# 9    2.21
# Name: Altura, dtype: float64

# %%
print(f"A media do CEP eh:\n{df['CEP']}")
# Out:
# A media do CEP eh:
# 0    35400278
# 1    30200198
# 2    54599549
# 3    34999178
# 4    20595958
# 5    22595395
# 6    29545190
# 7    54999111
# 8    28540908
# 9    98595918
# Name: CEP, dtype: int64

# %% [markdown]
# #count e usado para contar a quantidade de tabela dos dados da pessoa

# %%
print(df.count())
# Out:
# Idade      10
# CPF        10
# Altura     10
# Salario    10
# CEP        10
# dtype: int64

# %%
df['Idade'].count()
# Out:
# np.int64(10)

# %%
df['CPF'].count()
# Out:
# np.int64(10)

# %%
# df['Idioma nativa'].count()

# %%
df['Altura'].count()
# Out:
# np.int64(10)

# %%
df['Salario'].count()
# Out:
# np.int64(10)

# %%
df["CEP"].count()
# Out:
# np.int64(10)

# %% [markdown]
# #tail e usado para visualizar a ultima linha da tabela

# %%
print(df.tail())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
print(df['Idade'].tail())
# Out:
# 5    50
# 6    60
# 7    56
# 8    74
# 9    80
# Name: Idade, dtype: int64

# %%
print(df['CPF'])
# Out:
# 0    129394934199
# 1    299934234190
# 2    944599690199
# 3    234539599134
# 4    539634870230
# 5    560495434139
# 6    699649665199
# 7    795740749239
# 8    734546634539
# 9    895995795695
# Name: CPF, dtype: int64

# %%
# print(df['Idioma nativa'].tail())

# %%
print(df['Altura'].tail())
# Out:
# 5    1.95
# 6    1.75
# 7    1.89
# 8    2.00
# 9    2.21
# Name: Altura, dtype: float64

# %%
print(df['Salario'].tail())
# Out:
# 5    2954
# 6    5099
# 7    5595
# 8    5454
# 9    4959
# Name: Salario, dtype: int64

# %%
print(df['CEP'].tail())
# Out:
# 5    22595395
# 6    29545190
# 7    54999111
# 8    28540908
# 9    98595918
# Name: CEP, dtype: int64

# %% [markdown]
# #value_counts

# %%
print(df.value_counts())
# Out:
# Idade  CPF           Altura  Salario  CEP
# 12     944599690199  1.85    4095     54599549    1
# 15     299934234190  1.79    5995     30200198    1
# 18     129394934199  1.83    5000     35400278    1
# 29     234539599134  1.55    4954     34999178    1
# 34     539634870230  1.59    3954     20595958    1
# 50     560495434139  1.95    2954     22595395    1
# 56     795740749239  1.89    5595     54999111    1
# 60     699649665199  1.75    5099     29545190    1
# 74     734546634539  2.00    5454     28540908    1
# 80     895995795695  2.21    4959     98595918    1
# Name: count, dtype: int64

# %%
print(df['Idade'].value_counts())
# Out:
# Idade
# 18    1
# 15    1
# 12    1
# 29    1
# 34    1
# 50    1
# 60    1
# 56    1
# 74    1
# 80    1
# Name: count, dtype: int64

# %%
print(df['CPF'].value_counts())
# Out:
# CPF
# 129394934199    1
# 299934234190    1
# 944599690199    1
# 234539599134    1
# 539634870230    1
# 560495434139    1
# 699649665199    1
# 795740749239    1
# 734546634539    1
# 895995795695    1
# Name: count, dtype: int64

# %%
# print(df['Idioma nativa'].value_counts())

# %%
print(df['Altura'].value_counts())
# Out:
# Altura
# 1.83    1
# 1.79    1
# 1.85    1
# 1.55    1
# 1.59    1
# 1.95    1
# 1.75    1
# 1.89    1
# 2.00    1
# 2.21    1
# Name: count, dtype: int64

# %%
print(df['Salario'].value_counts())
# Out:
# Salario
# 5000    1
# 5995    1
# 4095    1
# 4954    1
# 3954    1
# 2954    1
# 5099    1
# 5595    1
# 5454    1
# 4959    1
# Name: count, dtype: int64

# %%
print(df['CEP'].value_counts())
# Out:
# CEP
# 35400278    1
# 30200198    1
# 54599549    1
# 34999178    1
# 20595958    1
# 22595395    1
# 29545190    1
# 54999111    1
# 28540908    1
# 98595918    1
# Name: count, dtype: int64

# %% [markdown]
# #corr

# %%
print(df.corr(numeric_only=True))
# Out:
#             Idade       CPF    Altura   Salario       CEP
# Idade    1.000000  0.544128  0.611567  0.087638  0.364061
# CPF      0.544128  1.000000  0.553988 -0.133788  0.532082
# Altura   0.611567  0.553988  1.000000  0.045627  0.655372
# Salario  0.087638 -0.133788  0.045627  1.000000  0.186964
# CEP      0.364061  0.532082  0.655372  0.186964  1.000000

# %%
df.corr(numeric_only=True)['Idade']
# Out:
# Idade      1.000000
# CPF        0.544128
# Altura     0.611567
# Salario    0.087638
# CEP        0.364061
# Name: Idade, dtype: float64

# %%
df.corr(numeric_only=True)['CPF']
# Out:
# Idade      0.544128
# CPF        1.000000
# Altura     0.553988
# Salario   -0.133788
# CEP        0.532082
# Name: CPF, dtype: float64

# %%
df.corr(numeric_only=True)['Altura']
# Out:
# Idade      0.611567
# CPF        0.553988
# Altura     1.000000
# Salario    0.045627
# CEP        0.655372
# Name: Altura, dtype: float64

# %%
df.corr(numeric_only=True)['Salario']
# Out:
# Idade      0.087638
# CPF       -0.133788
# Altura     0.045627
# Salario    1.000000
# CEP        0.186964
# Name: Salario, dtype: float64

# %%
df.corr(numeric_only=True)['CEP']
# Out:
# Idade      0.364061
# CPF        0.532082
# Altura     0.655372
# Salario    0.186964
# CEP        1.000000
# Name: CEP, dtype: float64

# %% [markdown]
# #sum

# %%
print(df.sum())
# Out:
# Idade      4.280000e+02
# CPF        5.834532e+12
# Altura     1.841000e+01
# Salario    4.805900e+04
# CEP        4.100717e+08
# dtype: float64

# %%
(df['Idade'].sum())
# Out:
# np.int64(428)

# %%
(df['CPF'].sum())
# Out:
# np.int64(5834531606763)

# %%
df['Altura'].sum()
# Out:
# np.float64(18.41)

# %%
df['Salario'].sum()
# Out:
# np.int64(48059)

# %%
df['CEP'].sum()
# Out:
# np.int64(410071683)

# %% [markdown]
# #var

# %%
print(df)
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     18  129394934199    1.83     5000  35400278
# 1     15  299934234190    1.79     5995  30200198
# 2     12  944599690199    1.85     4095  54599549
# 3     29  234539599134    1.55     4954  34999178
# 4     34  539634870230    1.59     3954  20595958
# 5     50  560495434139    1.95     2954  22595395
# 6     60  699649665199    1.75     5099  29545190
# 7     56  795740749239    1.89     5595  54999111
# 8     74  734546634539    2.00     5454  28540908
# 9     80  895995795695    2.21     4959  98595918

# %%
df['Idade'].var()
# Out:
# 609.2888888888889

# %%
df['CPF'].var()
# Out:
# 8.002735868631849e+22

# %%
df['Altura'].var()
# Out:
# 0.037165555555555535

# %%
df['Salario'].var()
# Out:
# 809585.8777777777

# %%
df['CEP'].var()
# Out:
# 547078959260858.0

# %% [markdown]
# #describe()

# %%
print(df.describe())
# Out:
#            Idade           CPF     Altura      Salario           CEP
# count  10.000000  1.000000e+01  10.000000    10.000000  1.000000e+01
# mean   42.800000  5.834532e+11   1.841000  4805.900000  4.100717e+07
# std    24.683778  2.828911e+11   0.192784   899.769903  2.338972e+07
# min    12.000000  1.293949e+11   1.550000  2954.000000  2.059596e+07
# 25%    20.750000  3.598594e+11   1.760000  4309.750000  2.879198e+07
# 50%    42.000000  6.300725e+11   1.840000  4979.500000  3.259969e+07
# 75%    59.000000  7.804422e+11   1.935000  5365.250000  4.979973e+07
# max    80.000000  9.445997e+11   2.210000  5995.000000  9.859592e+07

# %%
df.describe()
# Out:
#            Idade           CPF     Altura      Salario           CEP
# count  10.000000  1.000000e+01  10.000000    10.000000  1.000000e+01
# mean   42.800000  5.834532e+11   1.841000  4805.900000  4.100717e+07
# std    24.683778  2.828911e+11   0.192784   899.769903  2.338972e+07
# min    12.000000  1.293949e+11   1.550000  2954.000000  2.059596e+07
# 25%    20.750000  3.598594e+11   1.760000  4309.750000  2.879198e+07
# 50%    42.000000  6.300725e+11   1.840000  4979.500000  3.259969e+07
# 75%    59.000000  7.804422e+11   1.935000  5365.250000  4.979973e+07
# max    80.000000  9.445997e+11   2.210000  5995.000000  9.859592e+07

# %%
print(df['Idade'].describe())
# Out:
# count    10.000000
# mean     42.800000
# std      24.683778
# min      12.000000
# 25%      20.750000
# 50%      42.000000
# 75%      59.000000
# max      80.000000
# Name: Idade, dtype: float64

# %%
print(df['CPF'].describe())
# Out:
# count    1.000000e+01
# mean     5.834532e+11
# std      2.828911e+11
# min      1.293949e+11
# 25%      3.598594e+11
# 50%      6.300725e+11
# 75%      7.804422e+11
# max      9.445997e+11
# Name: CPF, dtype: float64

# %%
print(df['Altura'].describe())
# Out:
# count    10.000000
# mean      1.841000
# std       0.192784
# min       1.550000
# 25%       1.760000
# 50%       1.840000
# 75%       1.935000
# max       2.210000
# Name: Altura, dtype: float64

# %%
print(df['Salario'].describe())
# Out:
# count      10.000000
# mean     4805.900000
# std       899.769903
# min      2954.000000
# 25%      4309.750000
# 50%      4979.500000
# 75%      5365.250000
# max      5995.000000
# Name: Salario, dtype: float64

# %%
print(df['CEP'].describe())
# Out:
# count    1.000000e+01
# mean     4.100717e+07
# std      2.338972e+07
# min      2.059596e+07
# 25%      2.879198e+07
# 50%      3.259969e+07
# 75%      4.979973e+07
# max      9.859592e+07
# Name: CEP, dtype: float64

# %% [markdown]
# #df['idade']mode()

# %%
print(df.mode())
# Out:
#    Idade           CPF  Altura  Salario       CEP
# 0     12  129394934199    1.55     2954  20595958
# 1     15  234539599134    1.59     3954  22595395
# 2     18  299934234190    1.75     4095  28540908
# 3     29  539634870230    1.79     4954  29545190
# 4     34  560495434139    1.83     4959  30200198
# 5     50  699649665199    1.85     5000  34999178
# 6     56  734546634539    1.89     5099  35400278
# 7     60  795740749239    1.95     5454  54599549
# 8     74  895995795695    2.00     5595  54999111
# 9     80  944599690199    2.21     5995  98595918

# %%
print(df['Idade'].mode())
# Out:
# 0    12
# 1    15
# 2    18
# 3    29
# 4    34
# 5    50
# 6    56
# 7    60
# 8    74
# 9    80
# Name: Idade, dtype: int64

# %%
# print(df['Idioma nativa'].mode())

# %%
print(df['Altura'].mode())
# Out:
# 0    1.55
# 1    1.59
# 2    1.75
# 3    1.79
# 4    1.83
# 5    1.85
# 6    1.89
# 7    1.95
# 8    2.00
# 9    2.21
# Name: Altura, dtype: float64

# %%
print(df['Salario'].mode())
# Out:
# 0    2954
# 1    3954
# 2    4095
# 3    4954
# 4    4959
# 5    5000
# 6    5099
# 7    5454
# 8    5595
# 9    5995
# Name: Salario, dtype: int64

# %%
print(df['CEP'].mode())
# Out:
# 0    20595958
# 1    22595395
# 2    28540908
# 3    29545190
# 4    30200198
# 5    34999178
# 6    35400278
# 7    54599549
# 8    54999111
# 9    98595918
# Name: CEP, dtype: int64

# %% [markdown]
# #plotagem

# %%
print('Idade vs Salario')
plt.scatter(df['Idade'], df['Salario'])
plt.title('Idade vs Salario')
plt.xlabel('Idade')
plt.ylabel('Salario')
plt.show()
# Out:
# Idade vs Salario

# %%
print('Idade vs Altura')
plt.scatter(df['Idade'], df['Altura'])
plt.title('Idade vs Altura')
plt.xlabel('Idade')
plt.ylabel('Altura')
plt.show()
# Out:
# Idade vs Altura
